# %% [markdown]
# # 고객 이탈 예측 및 마케팅 전략 최적화
# 1. 데이터 수집 및 전처리
# 2. 상태 및 행동 정의
# 3. 상태 전의 확률 및 보상 함수 추정
# 4. MDP 모델링 및 알고리즘 적용
# 5. 결과 해석 및 적용 방안 제시

# %% [markdown]
# ## 1. 데이터 로드 및 전처리

# %%
import pandas as pd
import numpy as np

# %%
# 데이터 로드
data = pd.read_excel('./online+retail+ii/online_retail_II.xlsx')

# %%
data
# Out:
#        Invoice StockCode                          Description  Quantity  \
# 0       489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1       489434    79323P                   PINK CHERRY LIGHTS        12
# 2       489434    79323W                  WHITE CHERRY LIGHTS        12
# 3       489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4       489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...        ...       ...                                  ...       ...
# 525456  538171     22271                 FELTCRAFT DOLL ROSIE         2
# 525457  538171     22750         FELTCRAFT PRINCESS LOLA DOLL         1
# 525458  538171     22751       FELTCRAFT PRINCESS OLIVIA DOLL         1
# 525459  538171     20970   PINK FLORAL FELTCRAFT SHOULDER BAG         2
# 525460  538171     21931               JUMBO STORAGE BAG SUKI         2
#
#                InvoiceDate  Price  Customer ID         Country
# 0      2009-12-01 07:45:00   6.95      13085.0  United Kingdom
# 1      2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 2      2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 3      2009-12-01 07:45:00   2.10      13085.0  United Kingdom
# 4      2009-12-01 07:45:00   1.25      13085.0  United Kingdom
# ...                    ...    ...          ...             ...
# 525456 2010-12-09 20:01:00   2.95      17530.0  United Kingdom
# 525457 2010-12-09 20:01:00   3.75      17530.0  United Kingdom
# 525458 2010-12-09 20:01:00   3.75      17530.0  United Kingdom
# 525459 2010-12-09 20:01:00   3.75      17530.0  United Kingdom
# 525460 2010-12-09 20:01:00   1.95      17530.0  United Kingdom
#
# [525461 rows x 8 columns]

# %%
# 필요한 열 선택 및 결측값 제거
data = data[['Customer ID', 'InvoiceDate', 'Invoice', 'Quantity', 'Price']].dropna()

# 데이터 타입 변환
data['InvoiceDate'] = pd.to_datetime(data['InvoiceDate'])
data['Customer ID'] = data['Customer ID'].astype(int)

# 고객별 마지막 구매 날짜 계산
last_purchase = data.groupby('Customer ID')['InvoiceDate'].max().reset_index()
last_purchase.columns = ['Customer ID', 'LastPurchaseDate']

# 현재 날짜 설정 (데이터 세트의 마지막 날짜로 설정)
current_date = data['InvoiceDate'].max()

# %%
# 고객의 상태 정의 함수
def define_customer_state(row):
    days_since_last_purchase = (current_date - row['LastPurchaseDate']).days
    if days_since_last_purchase <= 30:
        return 'Active'
    elif days_since_last_purchase <= 90:
        return 'Dormant'
    else:
        return 'Churned'
    
# 고객 상태 할당
last_purchase['State'] = last_purchase.apply(define_customer_state, axis=1)

# 상태별 고객 수 확인
print('상태별 고객 수:')
print(last_purchase['State'].value_counts())
# Out:
# 상태별 고객 수:
# State
# Active     1673
# Churned    1449
# Dormant    1261
# Name: count, dtype: int64

# %% [markdown]
# ## 2. 상태 전이 확률 추정

# %%
# 상태와 행동 정의
states = ['Active', 'Dormant', 'Churned']
actions = ['No Action', 'Email Campaign', 'Offer Discount']

# 상태 전이 확률 (임의 설정)
P = {
    'Active': {
        'No Action': {'Active': 0.6, 'Dormant': 0.3, 'Churned': 0.1},
        'Email Campaign': {'Active': 0.7, 'Dormant': 0.25, 'Churned': 0.05},
        'Offer Discount': {'Active': 0.8, 'Dormant': 0.15, 'Churned': 0.05}
    },
    'Dormant': {
        'No Action': {'Dormant': 0.5, 'Churned': 0.5},
        'Email Campaign': {'Active': 0.3, 'Dormant': 0.5, 'Churned': 0.2},
        'Offer Discount': {'Active': 0.5, 'Dormant': 0.4, 'Churned': 0.1}
    },
    'Churned': {
        'No Action': {'Churned': 1.0},
        'Email Campaign': {'Dormant': 0.2, 'Churned': 0.8},
        'Offer Discount': {'Active': 0.3, 'Churned': 0.7}
    }
}

# 보상 함수 정의 (고객의 상태와 행동에 따른 예상 수익)
R = {
    'Active': {'No Action': 10, 'Email Campaign': 8, 'Offer Discount': 6},
    'Dormant': {'No Action': 0, 'Email Campaign': 5, 'Offer Discount': 4},
    'Churned': {'No Action': -2, 'Email Campaign': 1, 'Offer Discount': 3}
}

# %% [markdown]
# ## 3. 가치 반복 알고리즘 구현

# %%
# 가치 함수 및 정책 초기화
V = {s:0 for s in states}
policy = {s: None for s in states}

# 가치 반복 알고리즘
gamma = 0.9  # 할인율
theta = 0.0001  # 수렴 임계값
iteration = 0

while True:
    delta = 0
    print(f'Iteration {iteration}')
    for s in states:
        v = V[s]
        action_values = {}
        for a in actions:
            total = 0
            for s_prime in P[s][a]:
                prob = P[s][a][s_prime]
                reward = R[s][a]
                total += prob * (reward + gamma * V[s_prime])
            action_values[a] = total
            print(f'  State {s}, Action {a}: Value {total:.2f}')
        best_action = max(action_values, key=action_values.get)
        V[s] = action_values[best_action]
        policy[s] = best_action
        delta = max(delta, abs(v - V[s]))
    iteration += 1
    print(f"    Updated Values: {V}")
    print(f"    Updated Policy: {policy}\n")
    if delta < theta:
        break
# Out:
# Iteration 0
#   State Active, Action No Action: Value 10.00
#   State Active, Action Email Campaign: Value 8.00
#   State Active, Action Offer Discount: Value 6.00
#   State Dormant, Action No Action: Value 0.00
#   State Dormant, Action Email Campaign: Value 7.70
#   State Dormant, Action Offer Discount: Value 8.50
#   State Churned, Action No Action: Value -2.00
#   State Churned, Action Email Campaign: Value 2.53
#   State Churned, Action Offer Discount: Value 5.70
#     Updated Values: {'Active': 10.0, 'Dormant': 8.5, 'Churned': 5.699999999999999}
#     Updated Policy: {'Active': 'No Action', 'Dormant': 'Offer Discount', 'Churned': 'Offer Discount'}
#
# Iteration 1
#   State Active, Action No Action: Value 18.21
#   State Active, Action Email Campaign: Value 16.47
#   State Active, Action Offer Discount: Value 14.60
#   State Dormant, Action No Action: Value 6.39
#   State Dormant, Action Email Campaign: Value 14.77
#   State Dormant, Action Offer Discount: Value 15.77
#   State Churned, Action No Action: Value 3.13
#   State Churned, Action Email Campaign: Value 7.94
#   State Churned, Action Offer Discount: Value 11.51
#     Updated Values: {'Active': 18.208, 'Dormant': 15.7666, 'Churned': 11.507159999999999}
#     Updated Policy: {'Active': 'No Action', 'Dormant': 'Offer Discount', 'Churned': 'Offer Discount'}
#
# Iteration 2
#   State Active, Action No Action: Value 25.12
#   State Active, Action Email Campaign: Value 23.54
#   State Active, Action Offer Discount: Value 21.76
#   State Dormant, Action No Action: Value 12.27
#   State Dormant, Action Email Campaign: Value 20.95
#   State Dormant, Action Offer Discount: Value 22.02
#   State Churned, Action No Action: Value 8.36
#   State Churned, Action Email Campaign: Value 13.25
#   State Churned, Action Offer Discount: Value 17.03
#     Updated Values: {'Active': 25.1249464, 'Dormant': 22.01784628, 'Churned': 17.033246327999997}
#     Updated Policy: {'Active': 'No Action', 'Dormant': 'Offer Discount', 'Churned': 'Offer Discount'}
#
# Iteration 3
#   State Active, Action No Action: Value 31.05
#   State Active, Action Email Campaign: Value 29.55
#   State Active, Action Offer Discount: Value 27.83
#   State Dormant, Action No Action: Value 17.57
#   State Dormant, Action Email Campaign: Value 26.36
#   State Dormant, Action Offer Discount: Value 27.43
#   State Churned, Action No Action: Value 13.33
#   State Churned, Action Email Campaign: Value 18.20
#   State Churned, Action Offer Discount: Value 22.11
#     Updated Values: {'Active': 31.04528172112, 'Dormant': 27.429793604824, 'Churned': 22.1131712513424}
#     Updated Policy: {'Active': 'No Action', 'Dormant': 'Offer Discount', 'Churned': 'Offer Discount'}
#
# Iteration 4
#   State Active, Action No Action: Value 36.16
#   State Active, Action Email Campaign: Value 34.73
#   State Active, Action Offer Discount: Value 33.05
#   State Dormant, Action No Action: Value 22.29
#   State Dormant, Action Email Campaign: Value 31.09
#   State Dormant, Action Offer Discount: Value 32.14
#   State Churned, Action No Action: Value 17.90
#   State Churned, Action Email Campaign: Value 22.71
#   State Churned, Action Offer Discount: Value 26.69
#     Updated Values: {'Active': 36.1606818153281, 'Dormant': 32.1372179272551, 'Churned': 26.694681978484297}
#     Updated Policy: {'Active': 'No Action', 'Dormant': 'Offer Discount', 'Churned': 'Offer Discount'}
#
# Iteration 5
#   State Active, Action No Action: Value 40.61
#   State Active, Action Email Campaign: Value 39.21
#   State Active, Action Offer Discount: Value 37.58
#   State Dormant, Action No Action: Value 26.47
#   State Dormant, Action Email Campaign: Value 35.23
#   State Dormant, Action Offer Discount: Value 36.24
#   State Churned, Action No Action: Value 22.03
#   State Churned, Action Email Campaign: Value 26.74
#   State Churned, Action Offer Discount: Value 30.78
#     Updated Values: {'Active': 40.606338398699634, 'Dormant': 36.24477211129026, 'Churned': 30.781361014094006}
#     Updated Policy: {'Active': 'No Action', 'Dormant': 'Offer Discount', 'Churned': 'Offer Discount'}
#
# Iteration 6
#   State Active, Action No Action: Value 44.48
#   State Active, Action Email Campaign: Value 43.12
#   State Active, Action Offer Discount: Value 41.51
#   State Dormant, Action No Action: Value 30.16
#   State Dormant, Action Email Campaign: Value 38.86
#   State Dormant, Action Offer Discount: Value 39.84
#   State Churned, Action No Action: Value 25.70
#   State Churned, Action Email Campaign: Value 30.33
#   State Churned, Action Offer Discount: Value 34.40
#     Updated Values: {'Active': 44.483833696614624, 'Dormant': 39.83616561480953, 'Churned': 34.40289253696517}
#     Updated Policy: {'Active': 'No Action', 'Dormant': 'Offer Discount', 'Churned': 'Offer Discount'}
#
# Iteration 7
#   State Active, Action No Action: Value 47.87
#   State Active, Action Email Campaign: Value 46.54
#   State Active, Action Offer Discount: Value 44.95
#   State Dormant, Action No Action: Value 33.41
#   State Dormant, Action Email Campaign: Value 42.04
#   State Dormant, Action Offer Discount: Value 42.98
#   State Churned, Action No Action: Value 28.96
#   State Churned, Action Email Campaign: Value 33.51
#   State Churned, Action Offer Discount: Value 37.60
#     Updated Values: {'Active': 47.87329524049733, 'Dormant': 42.98026280788209, 'Churned': 37.599612013222334}
#     Updated Policy: {'Active': 'No Action', 'Dormant': 'Offer Discount', 'Churned': 'Offer Discount'}
#
# Iteration 8
#   State Active, Action No Action: Value 50.84
#   State Active, Action Email Campaign: Value 49.52
#   State Active, Action Offer Discount: Value 47.96
#   State Dormant, Action No Action: Value 36.26
#   State Dormant, Action Email Campaign: Value 44.84
#   State Dormant, Action Offer Discount: Value 45.73
#   State Churned, Action No Action: Value 31.84
#   State Churned, Action Email Campaign: Value 36.30
#   State Churned, Action Offer Discount: Value 40.41
#     Updated Values: {'Active': 50.84021546918673, 'Dormant': 45.734956653161596, 'Churned': 40.414613745010485}
#     Updated Policy: {'Active': 'No Action', 'Dormant': 'Offer Discount', 'Churned': 'Offer Discount'}
#
# Iteration 9
#   State Active, Action No Action: Value 53.44
#   State Active, Action Email Campaign: Value 52.14
#   State Active, Action Offer Discount: Value 50.60
#   State Dormant, Action No Action: Value 38.77
#   State Dormant, Action Email Campaign: Value 47.28
#   State Dormant, Action Offer Discount: Value 48.15
#   State Churned, Action No Action: Value 34.37
#   State Churned, Action Email Campaign: Value 38.77
#   State Churned, Action Offer Discount: Value 42.89
#     Updated Values: {'Active': 53.43946988676541, 'Dormant': 48.14966108123356, 'Churned': 42.889863528783266}
#     Updated Policy: {'Active': 'No Action', 'Dormant': 'Offer Discount', 'Churned': 'Offer Discount'}
#
# Iteration 10
#   State Active, Action No Action: Value 55.72
#   State Active, Action Email Campaign: Value 54.43
#   State Active, Action Offer Discount: Value 52.91
#   State Dormant, Action No Action: Value 40.97
#   State Dormant, Action Email Campaign: Value 49.43
#   State Dormant, Action Offer Discount: Value 50.27
#   State Churned, Action No Action: Value 36.60
#   State Churned, Action Email Campaign: Value 40.93
#   State Churned, Action Offer Discount: Value 45.06
#     Updated Values: {'Active': 55.717809948376875, 'Dormant': 50.26698018360417, 'Churned': 45.06442270919521}
#     Updated Policy: {'Active': 'No Action', 'Dormant': 'Offer Discount', 'Churned': 'Offer Discount'}
#
# Iteration 11
#   State Active, Action No Action: Value 57.72
#   State Active, Action Email Campaign: Value 56.44
#   State Active, Action Offer Discount: Value 54.93
#   State Dormant, Action No Action: Value 42.90
#   State Dormant, Action Email Campaign: Value 51.31
#   State Dormant, Action Offer Discount: Value 52.12
#   State Churned, Action No Action: Value 38.56
#   State Churned, Action Email Campaign: Value 42.83
#   State Churned, Action Offer Discount: Value 46.97
#     Updated Values: {'Active': 57.7155000655242, 'Dormant': 52.12388593941097, 'Churned': 46.97377132448452}
#     Updated Policy: {'Active': 'No Action', 'Dormant': 'Offer Discount', 'Churned': 'Offer Discount'}
#
# Iteration 12
#   State Active, Action No Action: Value 59.47
#   State Active, Action Email Campaign: Value 58.20
#   State Active, Action Offer Discount: Value 56.71
#   State Dormant, Action No Action: Value 44.59
#   State Dormant, Action Email Campaign: Value 52.97
#   State Dormant, Action Offer Discount: Value 53.75
#   State Churned, Action No Action: Value 40.28
#   State Churned, Action Email Campaign: Value 44.50
#   State Churned, Action Offer Discount: Value 48.65
#     Updated Values: {'Active': 59.467458658227635, 'Dormant': 53.752594753593996, 'Churned': 48.6496897721467}
#     Updated Policy: {'Active': 'No Action', 'Dormant': 'Offer Discount', 'Churned': 'Offer Discount'}
#
# Iteration 13
#   State Active, Action No Action: Value 61.00
#   State Active, Action Email Campaign: Value 59.75
#   State Active, Action Offer Discount: Value 58.26
#   State Dormant, Action No Action: Value 46.08
#   State Dormant, Action Email Campaign: Value 54.42
#   State Dormant, Action Offer Discount: Value 55.18
#   State Churned, Action No Action: Value 41.78
#   State Churned, Action Email Campaign: Value 45.96
#   State Churned, Action Offer Discount: Value 50.12
#     Updated Values: {'Active': 61.0041003384065, 'Dormant': 55.181251343069974, 'Churned': 50.12041164782218}
#     Updated Policy: {'Active': 'No Action', 'Dormant': 'Offer Discount', 'Churned': 'Offer Discount'}
#
# Iteration 14
#   State Active, Action No Action: Value 62.35
#   State Active, Action Email Campaign: Value 61.10
#   State Active, Action Offer Discount: Value 59.63
#   State Dormant, Action No Action: Value 47.39
#   State Dormant, Action Email Campaign: Value 55.69
#   State Dormant, Action Offer Discount: Value 56.43
#   State Churned, Action No Action: Value 43.11
#   State Churned, Action Email Campaign: Value 47.24
#   State Churned, Action Offer Discount: Value 51.41
#     Updated Values: {'Active': 62.3519890936724, 'Dormant': 56.43448262396176, 'Churned': 51.41089639341952}
#     Updated Policy: {'Active': 'No Action', 'Dormant': 'Offer Discount', 'Churned': 'Offer Discount'}
#
# Iteration 15
#   State Active, Action No Action: Value 63.53
#   State Active, Action Email Campaign: Value 62.29
#   State Active, Action Offer Discount: Value 60.83
#   State Dormant, Action No Action: Value 48.53
#   State Dormant, Action Email Campaign: Value 56.80
#   State Dormant, Action Offer Discount: Value 57.53
#   State Churned, Action No Action: Value 44.27
#   State Churned, Action Email Campaign: Value 48.37
#   State Churned, Action Offer Discount: Value 52.54
#     Updated Values: {'Active': 63.534365094460526, 'Dormant': 57.53385871254123, 'Churned': 52.54314330335864}
#     Updated Policy: {'Active': 'No Action', 'Dormant': 'Offer Discount', 'Churned': 'Offer Discount'}
#
# Iteration 16
#   State Active, Action No Action: Value 64.57
#   State Active, Action Email Campaign: Value 63.34
#   State Active, Action Offer Discount: Value 61.88
#   State Dormant, Action No Action: Value 49.53
#   State Dormant, Action Email Campaign: Value 57.78
#   State Dormant, Action Offer Discount: Value 58.50
#   State Churned, Action No Action: Value 45.29
#   State Churned, Action Email Campaign: Value 49.36
#   State Churned, Action Offer Discount: Value 53.54
#     Updated Values: {'Active': 64.57158190069708, 'Dormant': 58.49828388913081, 'Churned': 53.53650739430415}
#     Updated Policy: {'Active': 'No Action', 'Dormant': 'Offer Discount', 'Churned': 'Offer Discount'}
#
# Iteration 17
#   State Active, Action No Action: Value 65.48
#   State Active, Action Email Campaign: Value 64.25
#   State Active, Action Offer Discount: Value 62.80
#   State Dormant, Action No Action: Value 50.42
#   State Dormant, Action Email Campaign: Value 58.64
#   State Dormant, Action Offer Discount: Value 59.34
#   State Churned, Action No Action: Value 46.18
#   State Churned, Action Email Campaign: Value 50.23
#   State Churned, Action Offer Discount: Value 54.41
#     Updated Values: {'Active': 65.48147654192913, 'Dormant': 59.34433230944258, 'Churned': 54.407998324732475}
#     Updated Policy: {'Active': 'No Action', 'Dormant': 'Offer Discount', 'Churned': 'Offer Discount'}
#
# Iteration 18
#   State Active, Action No Action: Value 66.28
#   State Active, Action Email Campaign: Value 65.05
#   State Active, Action Offer Discount: Value 63.61
#   State Dormant, Action No Action: Value 51.19
#   State Dormant, Action Email Campaign: Value 59.39
#   State Dormant, Action Offer Discount: Value 60.09
#   State Churned, Action No Action: Value 46.97
#   State Churned, Action Email Campaign: Value 50.99
#   State Churned, Action Offer Discount: Value 55.17
#     Updated Values: {'Active': 66.27968690541715, 'Dormant': 60.08653858806297, 'Churned': 55.17255440904409}
#     Updated Policy: {'Active': 'No Action', 'Dormant': 'Offer Discount', 'Churned': 'Offer Discount'}
#
# Iteration 19
#   State Active, Action No Action: Value 66.98
#   State Active, Action Email Campaign: Value 65.76
#   State Active, Action Offer Discount: Value 64.32
#   State Dormant, Action No Action: Value 51.87
#   State Dormant, Action Email Campaign: Value 60.05
#   State Dormant, Action Offer Discount: Value 60.74
#   State Churned, Action No Action: Value 47.66
#   State Churned, Action Email Campaign: Value 51.66
#   State Churned, Action Offer Discount: Value 55.84
#     Updated Values: {'Active': 66.97992624451624, 'Dormant': 60.73765059854895, 'Churned': 55.84328936371716}
#     Updated Policy: {'Active': 'No Action', 'Dormant': 'Offer Discount', 'Churned': 'Offer Discount'}
#
# Iteration 20
#   State Active, Action No Action: Value 67.59
#   State Active, Action Email Campaign: Value 66.38
#   State Active, Action Offer Discount: Value 64.94
#   State Dormant, Action No Action: Value 52.46
#   State Dormant, Action Email Campaign: Value 60.63
#   State Dormant, Action Offer Discount: Value 61.31
#   State Churned, Action No Action: Value 48.26
#   State Churned, Action Email Campaign: Value 52.24
#   State Churned, Action Offer Discount: Value 56.43
#     Updated Values: {'Active': 67.59422187638154, 'Dormant': 61.30885010258386, 'Churned': 56.431712205764825}
#     Updated Policy: {'Active': 'No Action', 'Dormant': 'Offer Discount', 'Churned': 'Offer Discount'}
#
# Iteration 21
#   State Active, Action No Action: Value 68.13
#   State Active, Action Email Campaign: Value 66.92
#   State Active, Action Offer Discount: Value 65.48
#   State Dormant, Action No Action: Value 52.98
#   State Dormant, Action Email Campaign: Value 61.14
#   State Dormant, Action Offer Discount: Value 61.81
#   State Churned, Action No Action: Value 48.79
#   State Churned, Action Email Campaign: Value 52.76
#   State Churned, Action Offer Discount: Value 56.95
#     Updated Values: {'Active': 68.13312343946251, 'Dormant': 61.80994568320716, 'Churned': 56.94792201828672}
#     Updated Policy: {'Active': 'No Action', 'Dormant': 'Offer Discount', 'Churned': 'Offer Discount'}
#
# Iteration 22
#   State Active, Action No Action: Value 68.61
#   State Active, Action Email Campaign: Value 67.39
#   State Active, Action Offer Discount: Value 65.96
#   State Dormant, Action No Action: Value 53.44
#   State Dormant, Action Email Campaign: Value 61.59
#   State Dormant, Action Offer Discount: Value 62.25
#   State Churned, Action No Action: Value 49.25
#   State Churned, Action Email Campaign: Value 53.21
#   State Churned, Action Offer Discount: Value 57.40
#     Updated Values: {'Active': 68.6058849734215, 'Dormant': 62.24954166564006, 'Churned': 57.40077981434443}
#     Updated Policy: {'Active': 'No Action', 'Dormant': 'Offer Discount', 'Churned': 'Offer Discount'}
#
# Iteration 23
#   State Active, Action No Action: Value 69.02
#   State Active, Action Email Campaign: Value 67.81
#   State Active, Action Offer Discount: Value 66.38
#   State Dormant, Action No Action: Value 53.84
#   State Dormant, Action Email Campaign: Value 61.98
#   State Dormant, Action Offer Discount: Value 62.64
#   State Churned, Action No Action: Value 49.66
#   State Churned, Action Email Campaign: Value 53.60
#   State Churned, Action Offer Discount: Value 57.80
#     Updated Values: {'Active': 69.02062431866142, 'Dormant': 62.63518612631907, 'Churned': 57.79805984907557}
#     Updated Policy: {'Active': 'No Action', 'Dormant': 'Offer Discount', 'Churned': 'Offer Discount'}
#
# Iteration 24
#   State Active, Action No Action: Value 69.38
#   State Active, Action Email Campaign: Value 68.18
#   State Active, Action Offer Discount: Value 66.75
#   State Dormant, Action No Action: Value 54.19
#   State Dormant, Action Email Campaign: Value 62.32
#   State Dormant, Action Offer Discount: Value 62.97
#   State Churned, Action No Action: Value 50.02
#   State Churned, Action Email Campaign: Value 53.95
#   State Churned, Action Offer Discount: Value 58.15
#     Updated Values: {'Active': 69.38446277260012, 'Dormant': 62.97350063956172, 'Churned': 58.146582653519644}
#     Updated Policy: {'Active': 'No Action', 'Dormant': 'Offer Discount', 'Churned': 'Offer Discount'}
#
# Iteration 25
#   State Active, Action No Action: Value 69.70
#   State Active, Action Email Campaign: Value 68.50
#   State Active, Action Offer Discount: Value 67.07
#   State Dormant, Action No Action: Value 54.50
#   State Dormant, Action Email Campaign: Value 62.62
#   State Dormant, Action Offer Discount: Value 63.27
#   State Churned, Action No Action: Value 50.33
#   State Churned, Action Email Campaign: Value 54.25
#   State Churned, Action Offer Discount: Value 58.45
#     Updated Values: {'Active': 69.7036475087025, 'Dormant': 63.27029404797512, 'Churned': 58.45233189906705}
#     Updated Policy: {'Active': 'No Action', 'Dormant': 'Offer Discount', 'Churned': 'Offer Discount'}
#
# Iteration 26
#   State Active, Action No Action: Value 69.98
#   State Active, Action Email Campaign: Value 68.78
#   State Active, Action Offer Discount: Value 67.36
#   State Dormant, Action No Action: Value 54.78
#   State Dormant, Action Email Campaign: Value 62.89
#   State Dormant, Action Offer Discount: Value 63.53
#   State Churned, Action No Action: Value 50.61
#   State Churned, Action Email Campaign: Value 54.52
#   State Churned, Action Offer Discount: Value 58.72
#     Updated Values: {'Active': 69.98365891856866, 'Dormant': 63.530662241542984, 'Churned': 58.720557004425785}
#     Updated Policy: {'Active': 'No Action', 'Dormant': 'Offer Discount', 'Churned': 'Offer Discount'}
#
# Iteration 27
#   State Active, Action No Action: Value 70.23
#   State Active, Action Email Campaign: Value 69.03
#   State Active, Action Offer Discount: Value 67.61
#   State Dormant, Action No Action: Value 55.01
#   State Dormant, Action Email Campaign: Value 63.12
#   State Dormant, Action Offer Discount: Value 63.76
#   State Churned, Action No Action: Value 50.85
#   State Churned, Action Email Campaign: Value 54.76
#   State Churned, Action Offer Discount: Value 58.96
#     Updated Values: {'Active': 70.229304751642, 'Dormant': 63.7590756755927, 'Churned': 58.95586319573158}
#     Updated Policy: {'Active': 'No Action', 'Dormant': 'Offer Discount', 'Churned': 'Offer Discount'}
#
# Iteration 28
#   State Active, Action No Action: Value 70.44
#   State Active, Action Email Campaign: Value 69.24
#   State Active, Action Offer Discount: Value 67.83
#   State Dormant, Action No Action: Value 55.22
#   State Dormant, Action Email Campaign: Value 63.32
#   State Dormant, Action Offer Discount: Value 63.96
#   State Churned, Action No Action: Value 51.06
#   State Churned, Action Email Campaign: Value 54.96
#   State Churned, Action Offer Discount: Value 59.16
#     Updated Values: {'Active': 70.44480268591255, 'Dormant': 63.95945613948986, 'Churned': 59.162290538507285}
#     Updated Policy: {'Active': 'No Action', 'Dormant': 'Offer Discount', 'Churned': 'Offer Discount'}
#
# Iteration 29
#   State Active, Action No Action: Value 70.63
#   State Active, Action Email Campaign: Value 69.43
#   State Active, Action Offer Discount: Value 68.02
#   State Dormant, Action No Action: Value 55.40
#   State Dormant, Action Email Campaign: Value 63.50
#   State Dormant, Action Offer Discount: Value 64.14
#   State Churned, Action No Action: Value 51.25
#   State Churned, Action Email Campaign: Value 55.14
#   State Churned, Action Offer Discount: Value 59.34
#     Updated Values: {'Active': 70.6338527565207, 'Dormant': 64.13524409911632, 'Churned': 59.343383283520176}
#     Updated Policy: {'Active': 'No Action', 'Dormant': 'Offer Discount', 'Churned': 'Offer Discount'}
#
# Iteration 30
#   State Active, Action No Action: Value 70.80
#   State Active, Action Email Campaign: Value 69.60
#   State Active, Action Offer Discount: Value 68.19
#   State Dormant, Action No Action: Value 55.57
#   State Dormant, Action Email Campaign: Value 63.66
#   State Dormant, Action Offer Discount: Value 64.29
#   State Churned, Action No Action: Value 51.41
#   State Churned, Action Email Campaign: Value 55.30
#   State Churned, Action Offer Discount: Value 59.50
#     Updated Values: {'Active': 70.79970089079939, 'Dormant': 64.28945777205843, 'Churned': 59.50225070913354}
#     Updated Policy: {'Active': 'No Action', 'Dormant': 'Offer Discount', 'Churned': 'Offer Discount'}
#
# Iteration 31
#   State Active, Action No Action: Value 70.95
#   State Active, Action Email Campaign: Value 69.75
#   State Active, Action Offer Discount: Value 68.33
#   State Dormant, Action No Action: Value 55.71
#   State Dormant, Action Email Campaign: Value 63.80
#   State Dormant, Action Offer Discount: Value 64.42
#   State Churned, Action No Action: Value 51.55
#   State Churned, Action Email Campaign: Value 55.44
#   State Churned, Action Offer Discount: Value 59.64
#     Updated Values: {'Active': 70.94519464330946, 'Dormant': 64.42474495125232, 'Churned': 59.64162050044768}
#     Updated Policy: {'Active': 'No Action', 'Dormant': 'Offer Discount', 'Churned': 'Offer Discount'}
#
# Iteration 32
#   State Active, Action No Action: Value 71.07
#   State Active, Action Email Campaign: Value 69.87
#   State Active, Action Offer Discount: Value 68.46
#   State Dormant, Action No Action: Value 55.83
#   State Dormant, Action Email Campaign: Value 63.92
#   State Dormant, Action Offer Discount: Value 64.54
#   State Churned, Action No Action: Value 51.68
#   State Churned, Action Email Campaign: Value 55.56
#   State Churned, Action Offer Discount: Value 59.76
#     Updated Values: {'Active': 71.07283208926553, 'Dormant': 64.54342846766062, 'Churned': 59.763885579383725}
#     Updated Policy: {'Active': 'No Action', 'Dormant': 'Offer Discount', 'Churned': 'Offer Discount'}
#
# Iteration 33
#   State Active, Action No Action: Value 71.18
#   State Active, Action Email Campaign: Value 69.99
#   State Active, Action Offer Discount: Value 68.58
#   State Dormant, Action No Action: Value 55.94
#   State Dormant, Action Email Campaign: Value 64.02
#   State Dormant, Action Offer Discount: Value 64.65
#   State Churned, Action No Action: Value 51.79
#   State Churned, Action Email Campaign: Value 55.67
#   State Churned, Action Offer Discount: Value 59.87
#     Updated Values: {'Active': 71.18480471661628, 'Dormant': 64.6475460729797, 'Churned': 59.87114518849815}
#     Updated Policy: {'Active': 'No Action', 'Dormant': 'Offer Discount', 'Churned': 'Offer Discount'}
#
# Iteration 34
#   State Active, Action No Action: Value 71.28
#   State Active, Action Email Campaign: Value 70.09
#   State Active, Action Offer Discount: Value 68.67
#   State Dormant, Action No Action: Value 56.03
#   State Dormant, Action Email Campaign: Value 64.11
#   State Dormant, Action Offer Discount: Value 64.74
#   State Churned, Action No Action: Value 51.88
#   State Churned, Action Email Campaign: Value 55.76
#   State Churned, Action Offer Discount: Value 59.97
#     Updated Values: {'Active': 71.28303505364215, 'Dormant': 64.73888542737649, 'Churned': 59.96524093323721}
#     Updated Policy: {'Active': 'No Action', 'Dormant': 'Offer Discount', 'Churned': 'Offer Discount'}
#
# Iteration 35
#   State Active, Action No Action: Value 71.37
#   State Active, Action Email Campaign: Value 70.17
#   State Active, Action Offer Discount: Value 68.76
#   State Dormant, Action No Action: Value 56.12
#   State Dormant, Action Email Campaign: Value 64.20
#   State Dormant, Action Offer Discount: Value 64.82
#   State Churned, Action No Action: Value 51.97
#   State Churned, Action Email Campaign: Value 55.84
#   State Churned, Action Offer Discount: Value 60.05
#     Updated Values: {'Active': 71.36920967834976, 'Dormant': 64.81901479310429, 'Churned': 60.04778840109388}
#     Updated Policy: {'Active': 'No Action', 'Dormant': 'Offer Discount', 'Churned': 'Offer Discount'}
#
# Iteration 36
#   State Active, Action No Action: Value 71.44
#   State Active, Action Email Campaign: Value 70.25
#   State Active, Action Offer Discount: Value 68.84
#   State Dormant, Action No Action: Value 56.19
#   State Dormant, Action Email Campaign: Value 64.27
#   State Dormant, Action Offer Discount: Value 64.89
#   State Churned, Action No Action: Value 52.04
#   State Churned, Action Email Campaign: Value 55.91
#   State Churned, Action Offer Discount: Value 60.12
#     Updated Values: {'Active': 71.44480817654548, 'Dormant': 64.88930996106146, 'Churned': 60.12020490035643}
#     Updated Policy: {'Active': 'No Action', 'Dormant': 'Offer Discount', 'Churned': 'Offer Discount'}
#
# Iteration 37
#   State Active, Action No Action: Value 71.51
#   State Active, Action Email Campaign: Value 70.32
#   State Active, Action Offer Discount: Value 68.91
#   State Dormant, Action No Action: Value 56.25
#   State Dormant, Action Email Campaign: Value 64.33
#   State Dormant, Action Offer Discount: Value 64.95
#   State Churned, Action No Action: Value 52.11
#   State Churned, Action Email Campaign: Value 55.98
#   State Churned, Action Offer Discount: Value 60.18
#     Updated Values: {'Active': 71.51112854585323, 'Dormant': 64.95097787264817, 'Churned': 60.18373379460492}
#     Updated Policy: {'Active': 'No Action', 'Dormant': 'Offer Discount', 'Churned': 'Offer Discount'}
#
# Iteration 38
#   State Active, Action No Action: Value 71.57
#   State Active, Action Email Campaign: Value 70.37
#   State Active, Action Offer Discount: Value 68.96
#   State Dormant, Action No Action: Value 56.31
#   State Dormant, Action Email Campaign: Value 64.38
#   State Dormant, Action Offer Discount: Value 65.01
#   State Churned, Action No Action: Value 52.17
#   State Churned, Action Email Campaign: Value 56.03
#   State Churned, Action Offer Discount: Value 60.24
#     Updated Values: {'Active': 71.56930948189019, 'Dormant': 65.00507734251836, 'Churned': 60.239465850711454}
#     Updated Policy: {'Active': 'No Action', 'Dormant': 'Offer Discount', 'Churned': 'Offer Discount'}
#
# Iteration 39
#   State Active, Action No Action: Value 71.62
#   State Active, Action Email Campaign: Value 70.43
#   State Active, Action Offer Discount: Value 69.02
#   State Dormant, Action No Action: Value 56.36
#   State Dormant, Action Email Campaign: Value 64.43
#   State Dormant, Action Offer Discount: Value 65.05
#   State Churned, Action No Action: Value 52.22
#   State Churned, Action Email Campaign: Value 56.08
#   State Churned, Action Offer Discount: Value 60.29
#     Updated Values: {'Active': 71.6203499292647, 'Dormant': 65.05253723803976, 'Churned': 60.28835796684969}
#     Updated Policy: {'Active': 'No Action', 'Dormant': 'Offer Discount', 'Churned': 'Offer Discount'}
#
# Iteration 40
#   State Active, Action No Action: Value 71.67
#   State Active, Action Email Campaign: Value 70.47
#   State Active, Action Offer Discount: Value 69.06
#   State Dormant, Action No Action: Value 56.40
#   State Dormant, Action Email Campaign: Value 64.48
#   State Dormant, Action Offer Discount: Value 65.09
#   State Churned, Action No Action: Value 52.26
#   State Churned, Action Email Campaign: Value 56.12
#   State Churned, Action Offer Discount: Value 60.33
#     Updated Values: {'Active': 71.66512623309015, 'Dormant': 65.09417242760136, 'Churned': 60.33124960204964}
#     Updated Policy: {'Active': 'No Action', 'Dormant': 'Offer Discount', 'Churned': 'Offer Discount'}
#
# Iteration 41
#   State Active, Action No Action: Value 71.70
#   State Active, Action Email Campaign: Value 70.51
#   State Active, Action Offer Discount: Value 69.10
#   State Dormant, Action No Action: Value 56.44
#   State Dormant, Action Email Campaign: Value 64.51
#   State Dormant, Action Offer Discount: Value 65.13
#   State Churned, Action No Action: Value 52.30
#   State Churned, Action Email Campaign: Value 56.16
#   State Churned, Action Offer Discount: Value 60.37
#     Updated Values: {'Active': 71.70440718550552, 'Dormant': 65.13069777159845, 'Churned': 60.368877189377756}
#     Updated Policy: {'Active': 'No Action', 'Dormant': 'Offer Discount', 'Churned': 'Offer Discount'}
#
# Iteration 42
#   State Active, Action No Action: Value 71.74
#   State Active, Action Email Campaign: Value 70.54
#   State Active, Action Offer Discount: Value 69.14
#   State Dormant, Action No Action: Value 56.47
#   State Dormant, Action Email Campaign: Value 64.54
#   State Dormant, Action Offer Discount: Value 65.16
#   State Churned, Action No Action: Value 52.33
#   State Churned, Action Email Campaign: Value 56.19
#   State Churned, Action Offer Discount: Value 60.40
#     Updated Values: {'Active': 71.73886722554855, 'Dormant': 65.1627403963163, 'Churned': 60.401886780206084}
#     Updated Policy: {'Active': 'No Action', 'Dormant': 'Offer Discount', 'Churned': 'Offer Discount'}
#
# Iteration 43
#   State Active, Action No Action: Value 71.77
#   State Active, Action Email Campaign: Value 70.58
#   State Active, Action Offer Discount: Value 69.17
#   State Dormant, Action No Action: Value 56.50
#   State Dormant, Action Email Campaign: Value 64.57
#   State Dormant, Action Offer Discount: Value 65.19
#   State Churned, Action No Action: Value 52.36
#   State Churned, Action Email Campaign: Value 56.22
#   State Churned, Action Offer Discount: Value 60.43
#     Updated Values: {'Active': 71.76909801902015, 'Dormant': 65.19085046145149, 'Churned': 60.43084513666527}
#     Updated Policy: {'Active': 'No Action', 'Dormant': 'Offer Discount', 'Churned': 'Offer Discount'}
#
# Iteration 44
#   State Active, Action No Action: Value 71.80
#   State Active, Action Email Campaign: Value 70.60
#   State Active, Action Offer Discount: Value 69.19
#   State Dormant, Action No Action: Value 56.53
#   State Dormant, Action Email Campaign: Value 64.60
#   State Dormant, Action Offer Discount: Value 65.22
#   State Churned, Action No Action: Value 52.39
#   State Churned, Action Email Campaign: Value 56.25
#   State Churned, Action Offer Discount: Value 60.46
#     Updated Values: {'Active': 71.79561861716266, 'Dormant': 65.21551060614561, 'Churned': 60.456249462733034}
#     Updated Policy: {'Active': 'No Action', 'Dormant': 'Offer Discount', 'Churned': 'Offer Discount'}
#
# Iteration 45
#   State Active, Action No Action: Value 71.82
#   State Active, Action Email Campaign: Value 70.63
#   State Active, Action Offer Discount: Value 69.22
#   State Dormant, Action No Action: Value 56.55
#   State Dormant, Action Email Campaign: Value 64.62
#   State Dormant, Action Offer Discount: Value 65.24
#   State Churned, Action No Action: Value 52.41
#   State Churned, Action Email Campaign: Value 56.27
#   State Churned, Action Offer Discount: Value 60.48
#     Updated Values: {'Active': 71.81888436857312, 'Dormant': 65.2371442357163, 'Churned': 60.478535941036554}
#     Updated Policy: {'Active': 'No Action', 'Dormant': 'Offer Discount', 'Churned': 'Offer Discount'}
#
# Iteration 46
#   State Active, Action No Action: Value 71.84
#   State Active, Action Email Campaign: Value 70.65
#   State Active, Action Offer Discount: Value 69.24
#   State Dormant, Action No Action: Value 56.57
#   State Dormant, Action Email Campaign: Value 64.64
#   State Dormant, Action Offer Discount: Value 65.26
#   State Churned, Action No Action: Value 52.43
#   State Churned, Action Email Campaign: Value 56.29
#   State Churned, Action Offer Discount: Value 60.50
#     Updated Values: {'Active': 71.83929473736619, 'Dormant': 65.25612279136595, 'Churned': 60.4980872219419}
#     Updated Policy: {'Active': 'No Action', 'Dormant': 'Offer Discount', 'Churned': 'Offer Discount'}
#
# Iteration 47
#   State Active, Action No Action: Value 71.86
#   State Active, Action Email Campaign: Value 70.66
#   State Active, Action Offer Discount: Value 69.26
#   State Dormant, Action No Action: Value 56.59
#   State Dormant, Action Email Campaign: Value 64.66
#   State Dormant, Action Offer Discount: Value 65.27
#   State Churned, Action No Action: Value 52.45
#   State Churned, Action Email Campaign: Value 56.31
#   State Churned, Action Offer Discount: Value 60.52
#     Updated Values: {'Active': 71.85720016182132, 'Dormant': 65.27277212768611, 'Churned': 60.515238993515155}
#     Updated Policy: {'Active': 'No Action', 'Dormant': 'Offer Discount', 'Churned': 'Offer Discount'}
#
# Iteration 48
#   State Active, Action No Action: Value 71.87
#   State Active, Action Email Campaign: Value 70.68
#   State Active, Action Offer Discount: Value 69.27
#   State Dormant, Action No Action: Value 56.60
#   State Dormant, Action Email Campaign: Value 64.67
#   State Dormant, Action Offer Discount: Value 65.29
#   State Churned, Action No Action: Value 52.46
#   State Churned, Action Email Campaign: Value 56.32
#   State Churned, Action Offer Discount: Value 60.53
#     Updated Values: {'Active': 71.87290807127513, 'Dormant': 65.28737810745719, 'Churned': 60.53028574515883}
#     Updated Policy: {'Active': 'No Action', 'Dormant': 'Offer Discount', 'Churned': 'Offer Discount'}
#
# Iteration 49
#   State Active, Action No Action: Value 71.89
#   State Active, Action Email Campaign: Value 70.69
#   State Active, Action Offer Discount: Value 69.29
#   State Dormant, Action No Action: Value 56.62
#   State Dormant, Action Email Campaign: Value 64.68
#   State Dormant, Action Offer Discount: Value 65.30
#   State Churned, Action No Action: Value 52.48
#   State Churned, Action Email Campaign: Value 56.34
#   State Churned, Action Offer Discount: Value 60.54
#     Updated Values: {'Active': 71.8866881645663, 'Dormant': 65.30019150980372, 'Churned': 60.54348582388295}
#     Updated Policy: {'Active': 'No Action', 'Dormant': 'Offer Discount', 'Churned': 'Offer Discount'}
#
# Iteration 50
#   State Active, Action No Action: Value 71.90
#   State Active, Action Email Campaign: Value 70.71
#   State Active, Action Offer Discount: Value 69.30
#   State Dormant, Action No Action: Value 56.63
#   State Dormant, Action Email Campaign: Value 64.70
#   State Dormant, Action Offer Discount: Value 65.31
#   State Churned, Action No Action: Value 52.49
#   State Churned, Action Email Campaign: Value 56.35
#   State Churned, Action Offer Discount: Value 60.56
#     Updated Values: {'Active': 71.89877704066227, 'Dormant': 65.31143233597683, 'Churned': 60.555065870025075}
#     Updated Policy: {'Active': 'No Action', 'Dormant': 'Offer Discount', 'Churned': 'Offer Discount'}
#
# Iteration 51
#   State Active, Action No Action: Value 71.91
#   State Active, Action Email Campaign: Value 70.72
#   State Active, Action Offer Discount: Value 69.31
#   State Dormant, Action No Action: Value 56.64
#   State Dormant, Action Email Campaign: Value 64.71
#   State Dormant, Action Offer Discount: Value 65.32
#   State Churned, Action No Action: Value 52.50
#   State Churned, Action Email Campaign: Value 56.36
#   State Churned, Action Offer Discount: Value 60.57
#     Updated Values: {'Active': 71.90938226097363, 'Dormant': 65.32129358669206, 'Churned': 60.565224708578675}
#     Updated Policy: {'Active': 'No Action', 'Dormant': 'Offer Discount', 'Churned': 'Offer Discount'}
#
# Iteration 52
#   State Active, Action No Action: Value 71.92
#   State Active, Action Email Campaign: Value 70.73
#   State Active, Action Offer Discount: Value 69.32
#   State Dormant, Action No Action: Value 56.65
#   State Dormant, Action Email Campaign: Value 64.71
#   State Dormant, Action Offer Discount: Value 65.33
#   State Churned, Action No Action: Value 52.51
#   State Churned, Action Email Campaign: Value 56.37
#   State Churned, Action Offer Discount: Value 60.57
#     Updated Values: {'Active': 71.9186859131047, 'Dormant': 65.32994457587834, 'Churned': 60.57413676294283}
#     Updated Policy: {'Active': 'No Action', 'Dormant': 'Offer Discount', 'Churned': 'Offer Discount'}
#
# Iteration 53
#   State Active, Action No Action: Value 71.93
#   State Active, Action Email Campaign: Value 70.73
#   State Active, Action Offer Discount: Value 69.33
#   State Dormant, Action No Action: Value 56.66
#   State Dormant, Action Email Campaign: Value 64.72
#   State Dormant, Action Offer Discount: Value 65.34
#   State Churned, Action No Action: Value 52.52
#   State Churned, Action Email Campaign: Value 56.37
#   State Churned, Action Offer Discount: Value 60.58
#     Updated Values: {'Active': 71.92684773722854, 'Dormant': 65.33753383773391, 'Churned': 60.581955049705684}
#     Updated Policy: {'Active': 'No Action', 'Dormant': 'Offer Discount', 'Churned': 'Offer Discount'}
#
# Iteration 54
#   State Active, Action No Action: Value 71.93
#   State Active, Action Email Campaign: Value 70.74
#   State Active, Action Offer Discount: Value 69.33
#   State Dormant, Action No Action: Value 56.66
#   State Dormant, Action Email Campaign: Value 64.73
#   State Dormant, Action Offer Discount: Value 65.34
#   State Churned, Action No Action: Value 52.52
#   State Churned, Action Email Campaign: Value 56.38
#   State Churned, Action Offer Discount: Value 60.59
#     Updated Values: {'Active': 71.93400786876508, 'Dormant': 65.34419167700202, 'Churned': 60.588813805881145}
#     Updated Policy: {'Active': 'No Action', 'Dormant': 'Offer Discount', 'Churned': 'Offer Discount'}
#
# Iteration 55
#   State Active, Action No Action: Value 71.94
#   State Active, Action Email Campaign: Value 70.75
#   State Active, Action Offer Discount: Value 69.34
#   State Dormant, Action No Action: Value 56.67
#   State Dormant, Action Email Campaign: Value 64.73
#   State Dormant, Action Offer Discount: Value 65.35
#   State Churned, Action No Action: Value 52.53
#   State Churned, Action Email Campaign: Value 56.39
#   State Churned, Action Offer Discount: Value 60.59
#     Updated Values: {'Active': 71.94028924445298, 'Dormant': 65.35003240625387, 'Churned': 60.59483079370743}
#     Updated Policy: {'Active': 'No Action', 'Dormant': 'Offer Discount', 'Churned': 'Offer Discount'}
#
# Iteration 56
#   State Active, Action No Action: Value 71.95
#   State Active, Action Email Campaign: Value 70.75
#   State Active, Action Offer Discount: Value 69.35
#   State Dormant, Action No Action: Value 56.68
#   State Dormant, Action Email Campaign: Value 64.74
#   State Dormant, Action Offer Discount: Value 65.36
#   State Churned, Action No Action: Value 52.54
#   State Churned, Action Email Campaign: Value 56.39
#   State Churned, Action Offer Discount: Value 60.60
#     Updated Values: {'Active': 71.94579971312683, 'Dormant': 65.35515630859214, 'Churned': 60.600109322579925}
#     Updated Policy: {'Active': 'No Action', 'Dormant': 'Offer Discount', 'Churned': 'Offer Discount'}
#
# Iteration 57
#   State Active, Action No Action: Value 71.95
#   State Active, Action Email Campaign: Value 70.76
#   State Active, Action Offer Discount: Value 69.35
#   State Dormant, Action No Action: Value 56.68
#   State Dormant, Action Email Campaign: Value 64.74
#   State Dormant, Action Offer Discount: Value 65.36
#   State Churned, Action No Action: Value 52.54
#   State Churned, Action Email Campaign: Value 56.40
#   State Churned, Action Offer Discount: Value 60.60
#     Updated Values: {'Active': 71.95063388744056, 'Dormant': 65.35965135947362, 'Churned': 60.6047400228343}
#     Updated Policy: {'Active': 'No Action', 'Dormant': 'Offer Discount', 'Churned': 'Offer Discount'}
#
# Iteration 58
#   State Active, Action No Action: Value 71.95
#   State Active, Action Email Campaign: Value 70.76
#   State Active, Action Offer Discount: Value 69.36
#   State Dormant, Action No Action: Value 56.68
#   State Dormant, Action Email Campaign: Value 64.75
#   State Dormant, Action Offer Discount: Value 65.36
#   State Churned, Action No Action: Value 52.54
#   State Churned, Action Email Campaign: Value 56.40
#   State Churned, Action Offer Discount: Value 60.61
#     Updated Values: {'Active': 71.95487476833087, 'Dormant': 65.36359473721448, 'Churned': 60.60880240183494}
#     Updated Policy: {'Active': 'No Action', 'Dormant': 'Offer Discount', 'Churned': 'Offer Discount'}
#
# Iteration 59
#   State Active, Action No Action: Value 71.96
#   State Active, Action Email Campaign: Value 70.77
#   State Active, Action Offer Discount: Value 69.36
#   State Dormant, Action No Action: Value 56.69
#   State Dormant, Action Email Campaign: Value 64.75
#   State Dormant, Action Offer Discount: Value 65.37
#   State Churned, Action No Action: Value 52.55
#   State Churned, Action Email Campaign: Value 56.40
#   State Churned, Action Offer Discount: Value 60.61
#     Updated Values: {'Active': 71.95859517011172, 'Dormant': 65.36705414811264, 'Churned': 60.612366209086176}
#     Updated Policy: {'Active': 'No Action', 'Dormant': 'Offer Discount', 'Churned': 'Offer Discount'}
#
# Iteration 60
#   State Active, Action No Action: Value 71.96
#   State Active, Action Email Campaign: Value 70.77
#   State Active, Action Offer Discount: Value 69.36
#   State Dormant, Action No Action: Value 56.69
#   State Dormant, Action Email Campaign: Value 64.76
#   State Dormant, Action Offer Discount: Value 65.37
#   State Churned, Action No Action: Value 52.55
#   State Churned, Action Email Campaign: Value 56.41
#   State Churned, Action Offer Discount: Value 60.62
#     Updated Values: {'Active': 71.96185897066849, 'Dormant': 65.37008898893913, 'Churned': 60.61549263380478}
#     Updated Policy: {'Active': 'No Action', 'Dormant': 'Offer Discount', 'Churned': 'Offer Discount'}
#
# Iteration 61
#   State Active, Action No Action: Value 71.96
#   State Active, Action Email Campaign: Value 70.77
#   State Active, Action Offer Discount: Value 69.37
#   State Dormant, Action No Action: Value 56.69
#   State Dormant, Action Email Campaign: Value 64.76
#   State Dormant, Action Offer Discount: Value 65.37
#   State Churned, Action No Action: Value 52.55
#   State Churned, Action Email Campaign: Value 56.41
#   State Churned, Action Offer Discount: Value 60.62
#     Updated Values: {'Active': 71.96472220821698, 'Dormant': 65.37275136675817, 'Churned': 60.618235355515594}
#     Updated Policy: {'Active': 'No Action', 'Dormant': 'Offer Discount', 'Churned': 'Offer Discount'}
#
# Iteration 62
#   State Active, Action No Action: Value 71.97
#   State Active, Action Email Campaign: Value 70.77
#   State Active, Action Offer Discount: Value 69.37
#   State Dormant, Action No Action: Value 56.70
#   State Dormant, Action Email Campaign: Value 64.76
#   State Dormant, Action Offer Discount: Value 65.38
#   State Churned, Action No Action: Value 52.56
#   State Churned, Action Email Campaign: Value 56.41
#   State Churned, Action Offer Discount: Value 60.62
#     Updated Values: {'Active': 71.96723404345828, 'Dormant': 65.37508699358557, 'Churned': 60.62064146570855}
#     Updated Policy: {'Active': 'No Action', 'Dormant': 'Offer Discount', 'Churned': 'Offer Discount'}
#
# Iteration 63
#   State Active, Action No Action: Value 71.97
#   State Active, Action Email Campaign: Value 70.78
#   State Active, Action Offer Discount: Value 69.37
#   State Dormant, Action No Action: Value 56.70
#   State Dormant, Action Email Campaign: Value 64.76
#   State Dormant, Action Offer Discount: Value 65.38
#   State Churned, Action No Action: Value 52.56
#   State Churned, Action Email Campaign: Value 56.41
#   State Churned, Action Offer Discount: Value 60.62
#     Updated Values: {'Active': 71.96943760364934, 'Dormant': 65.37713597124679, 'Churned': 60.6227522763817}
#     Updated Policy: {'Active': 'No Action', 'Dormant': 'Offer Discount', 'Churned': 'Offer Discount'}
#
# Iteration 64
#   State Active, Action No Action: Value 71.97
#   State Active, Action Email Campaign: Value 70.78
#   State Active, Action Offer Discount: Value 69.37
#   State Dormant, Action No Action: Value 56.70
#   State Dormant, Action Email Campaign: Value 64.76
#   State Dormant, Action Offer Discount: Value 65.38
#   State Churned, Action No Action: Value 52.56
#   State Churned, Action Email Campaign: Value 56.42
#   State Churned, Action Offer Discount: Value 60.62
#     Updated Values: {'Active': 71.97137072308162, 'Dormant': 65.37893347990993, 'Churned': 60.62460402935251}
#     Updated Policy: {'Active': 'No Action', 'Dormant': 'Offer Discount', 'Churned': 'Offer Discount'}
#
# Iteration 65
#   State Active, Action No Action: Value 71.97
#   State Active, Action Email Campaign: Value 70.78
#   State Active, Action Offer Discount: Value 69.37
#   State Dormant, Action No Action: Value 56.70
#   State Dormant, Action Email Campaign: Value 64.77
#   State Dormant, Action Offer Discount: Value 65.38
#   State Churned, Action No Action: Value 52.56
#   State Churned, Action Email Campaign: Value 56.42
#   State Churned, Action Offer Discount: Value 60.63
#     Updated Values: {'Active': 71.97306659268148, 'Dormant': 65.38051038211596, 'Churned': 60.62622851851608}
#     Updated Policy: {'Active': 'No Action', 'Dormant': 'Offer Discount', 'Churned': 'Offer Discount'}
#
# Iteration 66
#   State Active, Action No Action: Value 71.97
#   State Active, Action Email Campaign: Value 70.78
#   State Active, Action Offer Discount: Value 69.38
#   State Dormant, Action No Action: Value 56.70
#   State Dormant, Action Email Campaign: Value 64.77
#   State Dormant, Action Offer Discount: Value 65.38
#   State Churned, Action No Action: Value 52.56
#   State Churned, Action Email Campaign: Value 56.42
#   State Churned, Action Offer Discount: Value 60.63
#     Updated Values: {'Active': 71.97455432988575, 'Dormant': 65.38189375267679, 'Churned': 60.627653635734276}
#     Updated Policy: {'Active': 'No Action', 'Dormant': 'Offer Discount', 'Churned': 'Offer Discount'}
#
# Iteration 67
#   State Active, Action No Action: Value 71.98
#   State Active, Action Email Campaign: Value 70.78
#   State Active, Action Offer Discount: Value 69.38
#   State Dormant, Action No Action: Value 56.70
#   State Dormant, Action Email Campaign: Value 64.77
#   State Dormant, Action Offer Discount: Value 65.38
#   State Churned, Action No Action: Value 52.56
#   State Churned, Action Email Campaign: Value 56.42
#   State Churned, Action Offer Discount: Value 60.63
#     Updated Values: {'Active': 71.97585947857712, 'Dormant': 65.38310734353944, 'Churned': 60.62890384972842}
#     Updated Policy: {'Active': 'No Action', 'Dormant': 'Offer Discount', 'Churned': 'Offer Discount'}
#
# Iteration 68
#   State Active, Action No Action: Value 71.98
#   State Active, Action Email Campaign: Value 70.78
#   State Active, Action Offer Discount: Value 69.38
#   State Dormant, Action No Action: Value 56.71
#   State Dormant, Action Email Campaign: Value 64.77
#   State Dormant, Action Offer Discount: Value 65.38
#   State Churned, Action No Action: Value 52.57
#   State Churned, Action Email Campaign: Value 56.42
#   State Churned, Action Offer Discount: Value 60.63
#     Updated Values: {'Active': 71.97700444766285, 'Dormant': 65.38417199159804, 'Churned': 60.63000062619787}
#     Updated Policy: {'Active': 'No Action', 'Dormant': 'Offer Discount', 'Churned': 'Offer Discount'}
#
# Iteration 69
#   State Active, Action No Action: Value 71.98
#   State Active, Action Email Campaign: Value 70.79
#   State Active, Action Offer Discount: Value 69.38
#   State Dormant, Action No Action: Value 56.71
#   State Dormant, Action Email Campaign: Value 64.77
#   State Dormant, Action Offer Discount: Value 65.39
#   State Churned, Action No Action: Value 52.57
#   State Churned, Action Email Campaign: Value 56.42
#   State Churned, Action Offer Discount: Value 60.63
#     Updated Values: {'Active': 71.97800889582722, 'Dormant': 65.38510597645535, 'Churned': 60.630962796378}
#     Updated Policy: {'Active': 'No Action', 'Dormant': 'Offer Discount', 'Churned': 'Offer Discount'}
#
# Iteration 70
#   State Active, Action No Action: Value 71.98
#   State Active, Action Email Campaign: Value 70.79
#   State Active, Action Offer Discount: Value 69.38
#   State Dormant, Action No Action: Value 56.71
#   State Dormant, Action Email Campaign: Value 64.77
#   State Dormant, Action Offer Discount: Value 65.39
#   State Churned, Action No Action: Value 52.57
#   State Churned, Action Email Campaign: Value 56.42
#   State Churned, Action Offer Discount: Value 60.63
#     Updated Values: {'Active': 71.97889006906367, 'Dormant': 65.3859253342766, 'Churned': 60.63180688036533}
#     Updated Policy: {'Active': 'No Action', 'Dormant': 'Offer Discount', 'Churned': 'Offer Discount'}
#
# Iteration 71
#   State Active, Action No Action: Value 71.98
#   State Active, Action Email Campaign: Value 70.79
#   State Active, Action Offer Discount: Value 69.38
#   State Dormant, Action No Action: Value 56.71
#   State Dormant, Action Email Campaign: Value 64.77
#   State Dormant, Action Offer Discount: Value 65.39
#   State Churned, Action No Action: Value 52.57
#   State Churned, Action Email Campaign: Value 56.42
#   State Churned, Action Offer Discount: Value 60.63
#     Updated Values: {'Active': 71.97966309678193, 'Dormant': 65.38664413312434, 'Churned': 60.63254737076127}
#     Updated Policy: {'Active': 'No Action', 'Dormant': 'Offer Discount', 'Churned': 'Offer Discount'}
#
# Iteration 72
#   State Active, Action No Action: Value 71.98
#   State Active, Action Email Campaign: Value 70.79
#   State Active, Action Offer Discount: Value 69.38
#   State Dormant, Action No Action: Value 56.71
#   State Dormant, Action Email Campaign: Value 64.77
#   State Dormant, Action Offer Discount: Value 65.39
#   State Churned, Action No Action: Value 52.57
#   State Churned, Action Email Campaign: Value 56.43
#   State Churned, Action Offer Discount: Value 60.63
#     Updated Values: {'Active': 71.98034125157432, 'Dormant': 65.38727471450171, 'Churned': 60.63319698150467}
#     Updated Policy: {'Active': 'No Action', 'Dormant': 'Offer Discount', 'Churned': 'Offer Discount'}
#
# Iteration 73
#   State Active, Action No Action: Value 71.98
#   State Active, Action Email Campaign: Value 70.79
#   State Active, Action Offer Discount: Value 69.38
#   State Dormant, Action No Action: Value 56.71
#   State Dormant, Action Email Campaign: Value 64.77
#   State Dormant, Action Offer Discount: Value 65.39
#   State Churned, Action No Action: Value 52.57
#   State Churned, Action Email Campaign: Value 56.43
#   State Churned, Action Offer Discount: Value 60.63
#     Updated Values: {'Active': 71.98093617710101, 'Dormant': 65.3878279052515, 'Churned': 60.63376686616521}
#     Updated Policy: {'Active': 'No Action', 'Dormant': 'Offer Discount', 'Churned': 'Offer Discount'}
#
# Iteration 74
#   State Active, Action No Action: Value 71.98
#   State Active, Action Email Campaign: Value 70.79
#   State Active, Action Offer Discount: Value 69.38
#   State Dormant, Action No Action: Value 56.71
#   State Dormant, Action Email Campaign: Value 64.77
#   State Dormant, Action Offer Discount: Value 65.39
#   State Churned, Action No Action: Value 52.57
#   State Churned, Action Email Campaign: Value 56.43
#   State Churned, Action Offer Discount: Value 60.63
#     Updated Values: {'Active': 71.98145808800732, 'Dormant': 65.3883132034487, 'Churned': 60.63426680944606}
#     Updated Policy: {'Active': 'No Action', 'Dormant': 'Offer Discount', 'Churned': 'Offer Discount'}
#
# Iteration 75
#   State Active, Action No Action: Value 71.98
#   State Active, Action Email Campaign: Value 70.79
#   State Active, Action Offer Discount: Value 69.38
#   State Dormant, Action No Action: Value 56.71
#   State Dormant, Action Email Campaign: Value 64.77
#   State Dormant, Action Offer Discount: Value 65.39
#   State Churned, Action No Action: Value 52.57
#   State Churned, Action Email Campaign: Value 56.43
#   State Churned, Action Offer Discount: Value 60.63
#     Updated Values: {'Active': 71.98191594530525, 'Dormant': 65.38873894147905, 'Churned': 60.63470539518343}
#     Updated Policy: {'Active': 'No Action', 'Dormant': 'Offer Discount', 'Churned': 'Offer Discount'}
#
# Iteration 76
#   State Active, Action No Action: Value 71.98
#   State Active, Action Email Campaign: Value 70.79
#   State Active, Action Offer Discount: Value 69.38
#   State Dormant, Action No Action: Value 56.71
#   State Dormant, Action Email Campaign: Value 64.77
#   State Dormant, Action Offer Discount: Value 65.39
#   State Churned, Action No Action: Value 52.57
#   State Churned, Action Email Campaign: Value 56.43
#   State Churned, Action Offer Discount: Value 60.64
#     Updated Values: {'Active': 71.98231761023068, 'Dormant': 65.38911242910277, 'Churned': 60.635090153727845}
#     Updated Policy: {'Active': 'No Action', 'Dormant': 'Offer Discount', 'Churned': 'Offer Discount'}
#
# Iteration 77
#   State Active, Action No Action: Value 71.98
#   State Active, Action Email Campaign: Value 70.79
#   State Active, Action Offer Discount: Value 69.38
#   State Dormant, Action No Action: Value 56.71
#   State Dormant, Action Email Campaign: Value 64.77
#   State Dormant, Action Offer Discount: Value 65.39
#   State Churned, Action No Action: Value 52.57
#   State Churned, Action Email Campaign: Value 56.43
#   State Churned, Action Offer Discount: Value 60.64
#     Updated Values: {'Active': 71.98266997921782, 'Dormant': 65.38944007896053, 'Churned': 60.63542769123735}
#     Updated Policy: {'Active': 'No Action', 'Dormant': 'Offer Discount', 'Churned': 'Offer Discount'}
#
# Iteration 78
#   State Active, Action No Action: Value 71.98
#   State Active, Action Email Campaign: Value 70.79
#   State Active, Action Offer Discount: Value 69.38
#   State Dormant, Action No Action: Value 56.71
#   State Dormant, Action Email Campaign: Value 64.78
#   State Dormant, Action Offer Discount: Value 65.39
#   State Churned, Action No Action: Value 52.57
#   State Churned, Action Email Campaign: Value 56.43
#   State Churned, Action Offer Discount: Value 60.64
#     Updated Values: {'Active': 71.98297910230833, 'Dormant': 65.3897275166759, 'Churned': 60.63572380310278}
#     Updated Policy: {'Active': 'No Action', 'Dormant': 'Offer Discount', 'Churned': 'Offer Discount'}
#
# Iteration 79
#   State Active, Action No Action: Value 71.98
#   State Active, Action Email Campaign: Value 70.79
#   State Active, Action Offer Discount: Value 69.38
#   State Dormant, Action No Action: Value 56.71
#   State Dormant, Action Email Campaign: Value 64.78
#   State Dormant, Action Offer Discount: Value 65.39
#   State Churned, Action No Action: Value 52.57
#   State Churned, Action Email Campaign: Value 56.43
#   State Churned, Action Offer Discount: Value 60.64
#     Updated Values: {'Active': 71.98325028702824, 'Dormant': 65.38997967744528, 'Churned': 60.63598357345238}
#     Updated Policy: {'Active': 'No Action', 'Dormant': 'Offer Discount', 'Churned': 'Offer Discount'}
#
# Iteration 80
#   State Active, Action No Action: Value 71.98
#   State Active, Action Email Campaign: Value 70.79
#   State Active, Action Offer Discount: Value 69.38
#   State Dormant, Action No Action: Value 56.71
#   State Dormant, Action Email Campaign: Value 64.78
#   State Dormant, Action Offer Discount: Value 65.39
#   State Churned, Action No Action: Value 52.57
#   State Churned, Action Email Campaign: Value 56.43
#   State Churned, Action Offer Discount: Value 60.64
#     Updated Values: {'Active': 71.9834881895162, 'Dormant': 65.3902008907733, 'Churned': 60.63621146244438}
#     Updated Policy: {'Active': 'No Action', 'Dormant': 'Offer Discount', 'Churned': 'Offer Discount'}
#
# Iteration 81
#   State Active, Action No Action: Value 71.98
#   State Active, Action Email Campaign: Value 70.79
#   State Active, Action Offer Discount: Value 69.38
#   State Dormant, Action No Action: Value 56.71
#   State Dormant, Action Email Campaign: Value 64.78
#   State Dormant, Action Offer Discount: Value 65.39
#   State Churned, Action No Action: Value 52.57
#   State Churned, Action Email Campaign: Value 56.43
#   State Churned, Action Offer Discount: Value 60.64
#     Updated Values: {'Active': 71.98369689446753, 'Dormant': 65.39039495480877, 'Churned': 60.63641138284619}
#     Updated Policy: {'Active': 'No Action', 'Dormant': 'Offer Discount', 'Churned': 'Offer Discount'}
#
# Iteration 82
#   State Active, Action No Action: Value 71.98
#   State Active, Action Email Campaign: Value 70.79
#   State Active, Action Offer Discount: Value 69.38
#   State Dormant, Action No Action: Value 56.71
#   State Dormant, Action Email Campaign: Value 64.78
#   State Dormant, Action Offer Discount: Value 65.39
#   State Churned, Action No Action: Value 52.57
#   State Churned, Action Email Campaign: Value 56.43
#   State Churned, Action Offer Discount: Value 60.64
#     Updated Values: {'Active': 71.983879985267, 'Dormant': 65.39056520155746, 'Churned': 60.63658676721519}
#     Updated Policy: {'Active': 'No Action', 'Dormant': 'Offer Discount', 'Churned': 'Offer Discount'}
#
# Iteration 83
#   State Active, Action No Action: Value 71.98
#   State Active, Action Email Campaign: Value 70.79
#   State Active, Action Offer Discount: Value 69.38
#   State Dormant, Action No Action: Value 56.71
#   State Dormant, Action Email Campaign: Value 64.78
#   State Dormant, Action Offer Discount: Value 65.39
#   State Churned, Action No Action: Value 52.57
#   State Churned, Action Email Campaign: Value 56.43
#   State Churned, Action Offer Discount: Value 60.64
#     Updated Values: {'Active': 71.98404060551405, 'Dormant': 65.39071455409139, 'Churned': 60.63674062683437}
#     Updated Policy: {'Active': 'No Action', 'Dormant': 'Offer Discount', 'Churned': 'Offer Discount'}
#
# Iteration 84
#   State Active, Action No Action: Value 71.98
#   State Active, Action Email Campaign: Value 70.79
#   State Active, Action Offer Discount: Value 69.38
#   State Dormant, Action No Action: Value 56.71
#   State Dormant, Action Email Campaign: Value 64.78
#   State Dormant, Action Offer Discount: Value 65.39
#   State Churned, Action No Action: Value 52.57
#   State Churned, Action Email Campaign: Value 56.43
#   State Churned, Action Offer Discount: Value 60.64
#     Updated Values: {'Active': 71.98418151299737, 'Dormant': 65.39084557673681, 'Churned': 60.63687560341494}
#     Updated Policy: {'Active': 'No Action', 'Dormant': 'Offer Discount', 'Churned': 'Offer Discount'}
#
# Iteration 85
#   State Active, Action No Action: Value 71.98
#   State Active, Action Email Campaign: Value 70.79
#   State Active, Action Offer Discount: Value 69.39
#   State Dormant, Action No Action: Value 56.71
#   State Dormant, Action Email Campaign: Value 64.78
#   State Dormant, Action Offer Discount: Value 65.39
#   State Churned, Action No Action: Value 52.57
#   State Churned, Action Email Campaign: Value 56.43
#   State Churned, Action Offer Discount: Value 60.64
#     Updated Values: {'Active': 71.98430512704486, 'Dormant': 65.39096051910278, 'Churned': 60.63699401445352}
#     Updated Policy: {'Active': 'No Action', 'Dormant': 'Offer Discount', 'Churned': 'Offer Discount'}
#
# Iteration 86
#   State Active, Action No Action: Value 71.98
#   State Active, Action Email Campaign: Value 70.79
#   State Active, Action Offer Discount: Value 69.39
#   State Dormant, Action No Action: Value 56.71
#   State Dormant, Action Email Campaign: Value 64.78
#   State Dormant, Action Offer Discount: Value 65.39
#   State Churned, Action No Action: Value 52.57
#   State Churned, Action Email Campaign: Value 56.43
#   State Churned, Action Offer Discount: Value 60.64
#     Updated Values: {'Active': 71.98441357006278, 'Dormant': 65.39106135470608, 'Churned': 60.63709789302267}
#     Updated Policy: {'Active': 'No Action', 'Dormant': 'Offer Discount', 'Churned': 'Offer Discount'}
#
# Iteration 87
#   State Active, Action No Action: Value 71.98
#   State Active, Action Email Campaign: Value 70.79
#   State Active, Action Offer Discount: Value 69.39
#   State Dormant, Action No Action: Value 56.71
#   State Dormant, Action Email Campaign: Value 64.78
#   State Dormant, Action Offer Discount: Value 65.39
#   State Churned, Action No Action: Value 52.57
#   State Churned, Action Email Campaign: Value 56.43
#   State Churned, Action Offer Discount: Value 60.64
#     Updated Values: {'Active': 71.98450870397659, 'Dormant': 65.3911498148557, 'Churned': 60.63718902267796}
#     Updated Policy: {'Active': 'No Action', 'Dormant': 'Offer Discount', 'Churned': 'Offer Discount'}

# %%
# 결과 출력
print('최종 가치 함수:')
for s in states:
    print(f'State {s}: {V[s]:.2f}')

print('\n최적 정책:')
for s in states:
    print(f'State {s}: {policy[s]}')
# Out:
# 최종 가치 함수:
# State Active: 71.98
# State Dormant: 65.39
# State Churned: 60.64
#
# 최적 정책:
# State Active: No Action
# State Dormant: Offer Discount
# State Churned: Offer Discount
